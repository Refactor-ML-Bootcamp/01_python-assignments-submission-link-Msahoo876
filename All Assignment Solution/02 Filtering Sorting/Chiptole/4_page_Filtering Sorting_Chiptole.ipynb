# %%
# Step 1. Import the necessary libraries
# Step 2. Import the dataset from this address.
# Step 3. Assign it to a variable called chipo.

import pandas as pd

# %%
chipo = pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv",sep='\t')
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
# Step 4. How many products cost more than $10.00?

chipo['item_price'] = chipo['item_price'].str.replace('$','')
chipo['item_price'] = chipo['item_price'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_792/140797292.py in <module>
#       1 # Step 4. How many products cost more than $10.00?
#       2
# ----> 3 chipo['item_price'] = chipo['item_price'].str.replace('$','')
#       4 chipo['item_price'] = chipo['item_price'].astype(float)
#
# ~\.conda\envs\tensorflow\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# ~\.conda\envs\tensorflow\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     179             # we're accessing the attribute of the class, i.e., Dataset.geo
#     180             return self._accessor
# --> 181         accessor_obj = self._accessor(obj)
# ...

# %%
greter = [i for i in chipo['item_price'] if i > 10.00]
total = len(greter)
total
# Out:
# 1130

# %%
# Step 5. What is the price of each item?
# print a data frame with only two columns item_name and item_price

chipo_1 = chipo.groupby('item_name')[['item_price']].min().reset_index()
chipo_1
# Out:
#                                 item_name  item_price
# 0                       6 Pack Soft Drink        6.49
# 1                           Barbacoa Bowl        8.69
# 2                        Barbacoa Burrito        8.69
# 3                   Barbacoa Crispy Tacos        8.99
# 4                     Barbacoa Salad Bowl        9.39
# 5                     Barbacoa Soft Tacos        8.99
# 6                           Bottled Water        1.09
# 7                                    Bowl        7.40
# 8                                 Burrito        7.40
# 9                             Canned Soda        1.09
# 10                      Canned Soft Drink        1.25
# 11                          Carnitas Bowl        8.99
# 12                       Carnitas Burrito        8.69
# 13                  Carnitas Crispy Tacos        8.99
# 14                         Carnitas Salad        8.99
# 15                    Carnitas Salad Bowl        9.39
# ...

# %%
# Step 6. Sort by the name of the item

chipo.sort_values(by='item_name', ascending=True).reset_index()
# Out:
#       index  order_id  quantity          item_name  \
# 0      3389      1360         2  6 Pack Soft Drink
# 1       341       148         1  6 Pack Soft Drink
# 2      1849       749         1  6 Pack Soft Drink
# 3      1860       754         1  6 Pack Soft Drink
# 4      2713      1076         1  6 Pack Soft Drink
# ...     ...       ...       ...                ...
# 4617   2384       948         1  Veggie Soft Tacos
# 4618    781       322         1  Veggie Soft Tacos
# 4619   2851      1132         1  Veggie Soft Tacos
# 4620   1699       688         1  Veggie Soft Tacos
# 4621   1395       567         1  Veggie Soft Tacos
#
#                                      choice_description  item_price
# 0                                           [Diet Coke]       12.98
# 1                                           [Diet Coke]        6.49
# 2                                                [Coke]        6.49
# 3                                           [Diet Coke]        6.49
# ...

# %%
# What was the quantity of the most expensive item ordered?

chipo_2 = chipo.groupby('quantity')['item_price'].max().reset_index()
chipo['quantity'].max()
# Out:
# 15

# %%
# Step 8. How many times was a Veggie Salad Bowl ordered?
cnt=0
for i in chipo['item_name']:
    if i == 'Veggie Salad Bowl':
        cnt = cnt + 1
print(cnt)
# Out:
# 18

# %%
# Step 9. How many times did someone order more than one Canned Soda

import 
chipo_3 = np.count_nonzero((chipo.item_name == "Canned Soda") & (chipo.quantity > 1))
print(chipo_3)
# Out:
# 1
